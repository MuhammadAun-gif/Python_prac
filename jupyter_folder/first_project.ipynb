# %%
import pandas as pd

# %%
simpsons = pd.read_html('https://simpsons.fandom.com/wiki/List_of_Episodes')

# %%
simpsons[2]
# Out:
#                                   Title    Original airdate Production code  \
# 0                    "Stark Raving Dad"  September 19, 1991            7F24
# 1                                   NaN                 NaN             NaN
# 2         "Mr. Lisa Goes to Washington"  September 26, 1991            8F01
# 3                                   NaN                 NaN             NaN
# 4                "When Flanders Failed"     October 3, 1991            7F23
# 5                                   NaN                 NaN             NaN
# 6                   "Bart the Murderer"    October 10, 1991            8F03
# 7                                   NaN                 NaN             NaN
# 8                       "Homer Defined"    October 17, 1991            8F04
# 9                                   NaN                 NaN             NaN
# 10            "Like Father, Like Clown"    October 24, 1991            8F05
# ...
