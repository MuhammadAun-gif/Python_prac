# %%
import pandas as pd

# %%
simpsons = pd.read_html('https://simpsons.fandom.com/wiki/List_of_Episodes')

# %%
simpsons[3]
# Out:
#                                            Title    Original airdate  \
# 0                                  "Kamp Krusty"  September 24, 1992
# 1                                            NaN                 NaN
# 2                      "A Streetcar Named Marge"     October 1, 1992
# 3                                            NaN                 NaN
# 4                            "Homer the Heretic"     October 8, 1992
# 5                                            NaN                 NaN
# 6                        "Lisa the Beauty Queen"    October 15, 1992
# 7                                            NaN                 NaN
# 8                      "Treehouse of Horror III"    October 29, 1992
# 9                                            NaN                 NaN
# 10                 "Itchy & Scratchy: The Movie"    November 3, 1992
# 11                                           NaN                 NaN
# 12                            "Marge Gets a Job"    November 5, 1992
# ...
